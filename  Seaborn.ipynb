# %% [markdown]
# # Seaborn
# ***
# ### Distribution Plots
# * sns.distplot(dataset['column_nmae' ],kde = 'false', bins = '')
#     * kde = that smoothening line that you see here ( kernal density Estimation)
#     * bins = overall estimation value
# * sns.jointplot(x = cnaem, y = cname , z = dataset) (used to compare the two numeric columns of the same table)
# * sns.pairplot(dataset,hue="categorical_column")(shows all the existing relationship between all the columns)
# * sns.rugplot(tips['column'])
# * sns.kdeplot(tips['column'])
#  ***
# ### Categorical Plots
# * sns.barplot(x = 'catergorical', y = 'numerical',data=, estimator = np.std )
# * sns.countplot(x = 'categorical')
# * sns.boxplot(x,y,data,hue)
# * sns.violinplot(x,y,data,hue,split = true)
# * sns.stripplot(x,y,data,jitter= 'True',split= 'true' )
#     *Jitter seperates the point from the same lines
# * sns.swarmpplot(x,y,data,jitter= 'True',split= 'true')
#  ***
# ### Matrix Plots
# >  The data must be in a matrix form i.e both the rows and columns must be in the  some sort of relevence
# * data.corr() (To make the corelation matrix)
# * data.pivot_table(index, colummn , values)
# * data.heatmap(data,annotate = 'True',cmap='magma', linecolor = '',linewidth )
# * data.clustermap()
# ***
# ### Grids
# they allow the different graphs to be assigned to the  just like subplots
# * pg = PairGrid(data)
#     * pg.map_upper(any_plot)
#     * pg.map_lower()
#     * pg.map_diag()
# * fg = FacetGrid(data,row, col)
#     * then map them according to the need
# ***
# ### Regression Plots
#  * sns.lmplot(x , y ,data ,hue)
#
# #### Styles
# * sns.despine() : to remove the top and right spine
# * sns.set_context('poster',font_scale = '')

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
sns.distplot(tips['total_bill'])
sns.jointplot(x='total_bill', y= 'tip', data = tips,kind='hex')
# Out:
# /Users/siddhantsarkar/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
